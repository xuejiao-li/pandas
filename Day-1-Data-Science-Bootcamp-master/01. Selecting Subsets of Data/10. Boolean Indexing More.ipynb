# %% [markdown]
# # 10. Boolean Indexing More
#
# ### Objectives
#
# + Boolean Selection with the brackets on a Series
# + Using the `between` method instead of an `and` condition
# + Simultaneously select rows with boolean selection and columns with a list of names with `.loc`
# + Select rows with missing values with the `isna` method

# %% [markdown]
# ## Boolean Selection on a Series
# All the examples thus far have taken place on the bikes DataFrame. Boolean selection on a Series happens almost identically. Since there is only one dimension of data, the queries you ask are usually going to be simpler.
#
# First, let’s select a single column of data as a Series such as the temperature column.

# %%
import pandas as pd
bikes = pd.read_csv('../data/bikes.csv', parse_dates=['starttime', 'stoptime'])

# %%
temp = bikes['temperature']
temp.head()
# Out:
# 0    73.9
# 1    69.1
# 2    73.0
# 3    72.0
# 4    73.0
# Name: temperature, dtype: float64

# %% [markdown]
# Let's select temperatures greater than 90

# %%
filt = temp > 90
temp[filt].head()
# Out:
# 54    91.0
# 55    91.0
# 56    91.0
# 61    93.0
# 62    93.0
# Name: temperature, dtype: float64

# %% [markdown]
# Select temperature less than 0 or greater than 95

# %%
# %pwd
# Out:
# '/Users/Allen/Desktop/Data Science Bootcamp/Day-1-Data-Science-Bootcamp-master/01. Selecting Subsets of Data'

# %%
filt1 = temp < 0
filt2 = temp > 95
filt = filt1 | filt2

temp[filt].head()
# Out:
# 395     96.1
# 396     96.1
# 397     96.1
# 1871    -2.0
# 2049    -2.0
# Name: temperature, dtype: float64

# %% [markdown]
# ## Re-read data with `starttime` in the index
# The default index is not very helpful. Let's re-read data with **`starttime`** in the index. While, this column may not be unique it does provide us with useful information for the index.

# %%
bikes = pd.read_csv('../data/bikes.csv', 
                    parse_dates=['starttime', 'stoptime'], 
                    index_col='starttime')
bikes.head()
# Out:
#                      trip_id    usertype gender            stoptime  \
# starttime
# 2013-06-28 19:01:00     7147  Subscriber   Male 2013-06-28 19:17:00
# 2013-06-28 22:53:00     7524  Subscriber   Male 2013-06-28 23:03:00
# 2013-06-30 14:43:00    10927  Subscriber   Male 2013-06-30 15:01:00
# 2013-07-01 10:05:00    12907  Subscriber   Male 2013-07-01 10:16:00
# 2013-07-01 11:16:00    13168  Subscriber   Male 2013-07-01 11:18:00
#
#                      tripduration             from_station_name  \
# starttime
# 2013-06-28 19:01:00           993     Lake Shore Dr & Monroe St
# 2013-06-28 22:53:00           623  Clinton St & Washington Blvd
# 2013-06-30 14:43:00          1040  Sheffield Ave & Kingsbury St
# 2013-07-01 10:05:00           667       Carpenter St & Huron St
# 2013-07-01 11:16:00           130        Damen Ave & Pierce Ave
#
#                      latitude_start  longitude_start  dpcapacity_start  \
# starttime
# 2013-06-28 19:01:00       41.881050       -87.616970              11.0
# 2013-06-28 22:53:00       41.883380       -87.641170              31.0
# 2013-06-30 14:43:00       41.909592       -87.653497              15.0
# 2013-07-01 10:05:00       41.894556       -87.653449              19.0
# 2013-07-01 11:16:00       41.909396       -87.677692              19.0
#
#                              to_station_name  latitude_end  longitude_end  \
# starttime
# 2013-06-28 19:01:00    Michigan Ave & Oak St     41.900960     -87.623777
# 2013-06-28 22:53:00     Wells St & Walton St     41.899930     -87.634430
# 2013-06-30 14:43:00  Dearborn St & Monroe St     41.881320     -87.629521
# 2013-07-01 10:05:00   Clark St & Randolph St     41.884576     -87.631890
# 2013-07-01 11:16:00   Damen Ave & Pierce Ave     41.909396     -87.677692
#
#                      dpcapacity_end  temperature  visibility  wind_speed  \
# starttime
# 2013-06-28 19:01:00            15.0         73.9        10.0        12.7
# 2013-06-28 22:53:00            19.0         69.1        10.0         6.9
# 2013-06-30 14:43:00            23.0         73.0        10.0        16.1
# 2013-07-01 10:05:00            31.0         72.0        10.0        16.1
# 2013-07-01 11:16:00            19.0         73.0        10.0        17.3
#
#                      precipitation        events
# starttime
# 2013-06-28 19:01:00        -9999.0  mostlycloudy
# 2013-06-28 22:53:00        -9999.0  partlycloudy
# 2013-06-30 14:43:00        -9999.0  mostlycloudy
# 2013-07-01 10:05:00        -9999.0  mostlycloudy
# 2013-07-01 11:16:00        -9999.0  partlycloudy

# %%
temp2 = bikes['temperature']
temp2.head()
# Out:
# starttime
# 2013-06-28 19:01:00    73.9
# 2013-06-28 22:53:00    69.1
# 2013-06-30 14:43:00    73.0
# 2013-07-01 10:05:00    72.0
# 2013-07-01 11:16:00    73.0
# Name: temperature, dtype: float64

# %% [markdown]
# Let's select temperatures greater than 90. We expect to get a summer month and we do.

# %%
filt = temp2 > 90
temp2[filt].head()
# Out:
# starttime
# 2013-07-16 15:13:00    91.0
# 2013-07-16 15:31:00    91.0
# 2013-07-16 16:35:00    91.0
# 2013-07-17 17:08:00    93.0
# 2013-07-17 17:25:00    93.0
# Name: temperature, dtype: float64

# %% [markdown]
# Select temperature less than 0 or greater than 95. We expect to get winter months and we do.

# %%
filt1 = temp2 < 0
filt2 = temp2 > 95
filt = filt1 | filt2

temp2[filt2].head()
# Out:
# starttime
# 2013-08-30 15:33:00    96.1
# 2013-08-30 15:37:00    96.1
# 2013-08-30 15:49:00    96.1
# Name: temperature, dtype: float64

# %% [markdown]
# ## The `between` method
# The `between` method return a boolean Series by testing whether the current value is between two given values. For instance, if want to select the temperatures between 50 and 60 degrees (inclusive), we do the following:

# %%
filt = temp2.between(50, 60)
filt.head()
# Out:
# starttime
# 2013-06-28 19:01:00    False
# 2013-06-28 22:53:00    False
# 2013-06-30 14:43:00    False
# 2013-07-01 10:05:00    False
# 2013-07-01 11:16:00    False
# Name: temperature, dtype: bool

# %%
temp2[filt].head()
# Out:
# starttime
# 2013-09-13 07:55:00    54.0
# 2013-09-13 08:04:00    57.9
# 2013-09-13 08:04:00    57.9
# 2013-09-13 08:06:00    57.9
# 2013-09-13 08:22:00    57.9
# Name: temperature, dtype: float64

# %% [markdown]
# # Simultaneous boolean selection of rows and column labels with `.loc`
# The **`.loc`** indexer was thoroughly covered in an earlier notebook and will now be covered here to simultaneously select rows and columns. Earlier, it was stated that **`.loc`** made selections only by label. This wasn't strictly true as it is also able to do boolean selection along with selection by label.
#
# Remember that **`.loc`** takes both a row selection and a column selection separated by a comma. Since the row selection comes first, you can pass it the same exact inputs that you do for just the brackets and get the same results.
#
# Let's run some of the older examples of boolean selection with **`.loc`**.

# %%
filt = bikes['tripduration'] > 1000
bikes.loc[filt].head()
# Out:
#                      trip_id    usertype gender            stoptime  \
# starttime
# 2013-06-30 14:43:00    10927  Subscriber   Male 2013-06-30 15:01:00
# 2013-07-03 15:21:00    21028  Subscriber   Male 2013-07-03 15:42:00
# 2013-07-04 17:17:00    24383  Subscriber   Male 2013-07-04 17:42:00
# 2013-07-04 18:13:00    24673  Subscriber   Male 2013-07-04 18:42:00
# 2013-07-05 10:02:00    26214  Subscriber   Male 2013-07-05 10:40:00
#
#                      tripduration             from_station_name  \
# starttime
# 2013-06-30 14:43:00          1040  Sheffield Ave & Kingsbury St
# 2013-07-03 15:21:00          1300  Clinton St & Washington Blvd
# 2013-07-04 17:17:00          1523           Morgan St & 18th St
# 2013-07-04 18:13:00          1697    Ashland Ave & Armitage Ave
# 2013-07-05 10:02:00          2263      Jefferson St & Monroe St
#
#                      latitude_start  longitude_start  dpcapacity_start  \
# starttime
# 2013-06-30 14:43:00       41.909592       -87.653497              15.0
# 2013-07-03 15:21:00       41.883380       -87.641170              31.0
# 2013-07-04 17:17:00       41.858086       -87.651073              15.0
# 2013-07-04 18:13:00       41.917859       -87.668919              15.0
# 2013-07-05 10:02:00       41.880422       -87.642746              19.0
#
#                                 to_station_name  latitude_end  longitude_end  \
# starttime
# 2013-06-30 14:43:00     Dearborn St & Monroe St     41.881320     -87.629521
# 2013-07-03 15:21:00       Wood St & Division St     41.903320     -87.672730
# 2013-07-04 17:17:00      Damen Ave & Pierce Ave     41.909396     -87.677692
# 2013-07-04 18:13:00  Lincoln Ave & Armitage Ave     41.918273     -87.638116
# 2013-07-05 10:02:00    Jefferson St & Monroe St     41.880422     -87.642746
#
#                      dpcapacity_end  temperature  visibility  wind_speed  \
# starttime
# 2013-06-30 14:43:00            23.0         73.0        10.0        16.1
# 2013-07-03 15:21:00            15.0         71.1         8.0         0.0
# 2013-07-04 17:17:00            19.0         79.0        10.0         9.2
# 2013-07-04 18:13:00            19.0         79.0        10.0        10.4
# 2013-07-05 10:02:00            19.0         79.0        10.0         0.0
#
#                      precipitation        events
# starttime
# 2013-06-30 14:43:00        -9999.0  mostlycloudy
# 2013-07-03 15:21:00        -9999.0        cloudy
# 2013-07-04 17:17:00        -9999.0  mostlycloudy
# 2013-07-04 18:13:00        -9999.0  mostlycloudy
# 2013-07-05 10:02:00        -9999.0  partlycloudy

# %%
filt = bikes['events'].isin(['rain', 'snow', 'tstorms', 'sleet'])
bikes.loc[filt].head()
# Out:
#                      trip_id    usertype  gender            stoptime  \
# starttime
# 2013-07-15 16:43:00    66336  Subscriber    Male 2013-07-15 16:55:00
# 2013-07-21 16:35:00    89180  Subscriber    Male 2013-07-21 17:06:00
# 2013-07-21 16:47:00    89228  Subscriber    Male 2013-07-21 17:03:00
# 2013-07-23 00:16:00    95044  Subscriber  Female 2013-07-23 00:26:00
# 2013-07-26 19:10:00   111568  Subscriber    Male 2013-07-26 19:33:00
#
#                      tripduration           from_station_name  latitude_start  \
# starttime
# 2013-07-15 16:43:00           727     Greenwood Ave & 47th St       41.809835
# 2013-07-21 16:35:00          1809   Michigan Ave & Pearson St       41.897660
# 2013-07-21 16:47:00           999     Carpenter St & Huron St       41.894556
# 2013-07-23 00:16:00           563   Wabash Ave & Roosevelt Rd       41.867173
# 2013-07-26 19:10:00          1395  Larrabee St & Kingsbury St       41.897764
#
#                      longitude_start  dpcapacity_start  \
# starttime
# 2013-07-15 16:43:00       -87.599383              15.0
# 2013-07-21 16:35:00       -87.623510              23.0
# 2013-07-21 16:47:00       -87.653449              19.0
# 2013-07-23 00:16:00       -87.625955              19.0
# 2013-07-26 19:10:00       -87.642884              27.0
#
#                              to_station_name  latitude_end  longitude_end  \
# starttime
# 2013-07-15 16:43:00   State St & Harrison St     41.873958     -87.627739
# 2013-07-21 16:35:00          Millennium Park     41.881032     -87.624084
# 2013-07-21 16:47:00  Carpenter St & Huron St     41.894556     -87.653449
# 2013-07-23 00:16:00       Daley Center Plaza     41.884337     -87.630183
# 2013-07-26 19:10:00   Damen Ave & Pierce Ave     41.909396     -87.677692
#
#                      dpcapacity_end  temperature  visibility  wind_speed  \
# starttime
# 2013-07-15 16:43:00            19.0         82.9        10.0         5.8
# 2013-07-21 16:35:00            35.0         82.4        10.0        11.5
# 2013-07-21 16:47:00            19.0         82.4        10.0        11.5
# 2013-07-23 00:16:00            47.0         78.8        10.0        17.3
# 2013-07-26 19:10:00            19.0         66.9         8.0        12.7
#
#                      precipitation   events
# starttime
# 2013-07-15 16:43:00            0.0     rain
# 2013-07-21 16:35:00            0.0  tstorms
# 2013-07-21 16:47:00            0.0  tstorms
# 2013-07-23 00:16:00            0.0  tstorms
# 2013-07-26 19:10:00            0.0     rain

# %% [markdown]
# ## Separate row and column selection with a comma for `.loc`
# The great benefit of **`.loc`** is that it allows us to simultaneously do boolean selection along the rows and make column selections by label.
#
# Let's select just the events rain and snow and only the columns events and trip duration.

# %%
filt = bikes['events'].isin(['rain', 'snow'])
cols = ['events', 'tripduration']
bikes.loc[filt, cols].head()
# Out:
#                     events  tripduration
# starttime
# 2013-07-15 16:43:00   rain           727
# 2013-07-26 19:10:00   rain          1395
# 2013-07-30 18:53:00   rain           442
# 2013-08-05 17:09:00   rain           890
# 2013-09-07 16:09:00   rain           978

# %% [markdown]
# ## Column to Column Comparisons
# So far, we have created conditionals by comparing each of our column values to a single scalar value. It is possible to do element-by-element comparisons by comparing two columns to one another.
#
# For instance, if we wanted to test whether there were more capacity at the start of the ride vs the end, we would do the following:

# %%
filt = bikes['dpcapacity_start'] > bikes['dpcapacity_end']

# %%
type(filt)
# Out:
# pandas.core.series.Series

# %% [markdown]
# Let's use this filter with **`.loc`** to return all the rows where the start capacity is greater than the end.

# %%
cols = ['dpcapacity_start', 'dpcapacity_end']
bikes.loc[filt, cols].head()
# Out:
#                      dpcapacity_start  dpcapacity_end
# starttime
# 2013-06-28 22:53:00              31.0            19.0
# 2013-07-02 17:47:00              31.0            19.0
# 2013-07-03 15:21:00              31.0            15.0
# 2013-07-07 00:06:00              19.0            15.0
# 2013-07-08 17:06:00              23.0            19.0

# %% [markdown]
# ### Boolean selection with `.iloc` does not work
# The Pandas developers decided not to allow boolean selection with **`.iloc`**.

# %%
bikes.iloc[filt]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-ab57beff3770> in <module>()
# ----> 1 bikes.iloc[filt]
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1476
#    1477             maybe_callable = com._apply_if_callable(key, self.obj)
# -> 1478             return self._getitem_axis(maybe_callable, axis=axis)
#    1479
#    1480     def _is_scalar_access(self, key):
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    2084
#    2085         if com.is_bool_indexer(key):
# -> 2086             self._validate_key(key, axis)
#    2087             return self._getbool_axis(key, axis=axis)
#    2088
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _validate_key(self, key, axis)
#    1948                                               "indexing on an integer type "
#    1949                                               "is not available")
# -> 1950                 raise ValueError("iLocation based boolean indexing cannot use "
#    1951                                  "an indexable as a mask")
#    1952             return
#
# ValueError: iLocation based boolean indexing cannot use an indexable as a mask

# %% [markdown]
# # Finding Missing Values with `isna`
# The **`isna`** method called from either a DataFrame or a Series returns True for every value that is missing and False for any other value.
#
# Let's see this in action by calling **`isna`** on the start capacity column.

# %%
bikes['dpcapacity_start'].isna().head()
# Out:
# starttime
# 2013-06-28 19:01:00    False
# 2013-06-28 22:53:00    False
# 2013-06-30 14:43:00    False
# 2013-07-01 10:05:00    False
# 2013-07-01 11:16:00    False
# Name: dpcapacity_start, dtype: bool

# %% [markdown]
# ### Filtering for missing values
#
# We can now use this boolean Series to select all the rows where the capacity start column is missing. Verify that the

# %%
filt = bikes['dpcapacity_start'].isna()
bikes[filt]

# %% [markdown]
# ## `isnull` is an alias for `isna`
# There is an identical method named **`isnull`** that you will see in other tutorials. It is an **alias** of **`isna`** meaning it does the exact same thing with a different name. Either one is suitable to use but I prefer **`isna`** because of the similarity **na** to **NaN**, the representation of missing values.

# %% [markdown]
# # Exercises

# %% [markdown]
# ### Problem 1
# <span  style="color:green; font-size:16px">Select the wind speed column a a Series and assign it to a variable. Are there any negative wind speeds?</span>

# %%
# your code here
filt = bikes['wind_speed'] < 0 
bikes.loc[filt, 'wind_speed'].head()
# Out:
# starttime
# 2016-03-19 10:08:00   -9999.0
# 2016-06-30 11:47:00   -9999.0
# 2016-07-21 21:02:29   -9999.0
# 2016-08-07 09:16:42   -9999.0
# 2016-08-07 09:29:44   -9999.0
# Name: wind_speed, dtype: float64

# %% [markdown]
# ### Problem 2
# <span  style="color:green; font-size:16px">Select all wind speed between 12 and 16.</span>

# %%
# your code here
filt = bikes['wind_speed'].between(12, 16)
bikes.loc[filt, 'wind_speed'].head()
# Out:
# starttime
# 2013-06-28 19:01:00    12.7
# 2013-07-02 17:47:00    15.0
# 2013-07-04 15:00:00    12.7
# 2013-07-09 13:12:00    13.8
# 2013-07-09 13:14:00    13.8
# Name: wind_speed, dtype: float64

# %% [markdown]
# ### Problem 3
# <span  style="color:green; font-size:16px">Select the events and gender columns for all trip durations longer than 1,000 seconds.</span>

# %%
# your code here
filt = bikes['tripduration'] > 1000
cols = ['events', 'gender']

# %%
bikes.loc[filt, cols].head()
# Out:
#                            events gender
# starttime
# 2013-06-30 14:43:00  mostlycloudy   Male
# 2013-07-03 15:21:00        cloudy   Male
# 2013-07-04 17:17:00  mostlycloudy   Male
# 2013-07-04 18:13:00  mostlycloudy   Male
# 2013-07-05 10:02:00  partlycloudy   Male

# %%
bikes.columns
# Out:
# Index(['trip_id', 'usertype', 'gender', 'stoptime', 'tripduration',
#        'from_station_name', 'latitude_start', 'longitude_start',
#        'dpcapacity_start', 'to_station_name', 'latitude_end', 'longitude_end',
#        'dpcapacity_end', 'temperature', 'visibility', 'wind_speed',
#        'precipitation', 'events'],
#       dtype='object')

# %% [markdown]
# ### Problem 4
# <span  style="color:green; font-size:16px">Read in the movie dataset with the title as the index. We will use this DataFrame for the rest of the problems. Select all the movies such that the Facebook likes for actor 2 are greater than those for actor 1.</span>

# %%
# your code here
movies = pd.read_csv('../data/movie.csv', index_col='title')
movies.head()
# Out:
#                                               year  color content_rating  \
# title
# Avatar                                      2009.0  Color          PG-13
# Pirates of the Caribbean: At World's End    2007.0  Color          PG-13
# Spectre                                     2015.0  Color          PG-13
# The Dark Knight Rises                       2012.0  Color          PG-13
# Star Wars: Episode VII - The Force Awakens     NaN    NaN            NaN
#
#                                             duration      director_name  \
# title
# Avatar                                         178.0      James Cameron
# Pirates of the Caribbean: At World's End       169.0     Gore Verbinski
# Spectre                                        148.0         Sam Mendes
# The Dark Knight Rises                          164.0  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens       NaN        Doug Walker
#
#                                             director_fb           actor1  \
# title
# Avatar                                              0.0      CCH Pounder
# Pirates of the Caribbean: At World's End          563.0      Johnny Depp
# Spectre                                             0.0  Christoph Waltz
# The Dark Knight Rises                           22000.0        Tom Hardy
# Star Wars: Episode VII - The Force Awakens        131.0      Doug Walker
#
#                                             actor1_fb            actor2  \
# title
# Avatar                                         1000.0  Joel David Moore
# Pirates of the Caribbean: At World's End      40000.0     Orlando Bloom
# Spectre                                       11000.0      Rory Kinnear
# The Dark Knight Rises                         27000.0    Christian Bale
# Star Wars: Episode VII - The Force Awakens      131.0        Rob Walker
#
#                                             actor2_fb     ...     actor3_fb  \
# title                                                     ...
# Avatar                                          936.0     ...         855.0
# Pirates of the Caribbean: At World's End       5000.0     ...        1000.0
# Spectre                                         393.0     ...         161.0
# The Dark Knight Rises                         23000.0     ...       23000.0
# Star Wars: Episode VII - The Force Awakens       12.0     ...           NaN
#
#                                                   gross  \
# title
# Avatar                                      760505847.0
# Pirates of the Caribbean: At World's End    309404152.0
# Spectre                                     200074175.0
# The Dark Knight Rises                       448130642.0
# Star Wars: Episode VII - The Force Awakens          NaN
#
#                                                                      genres  \
# title
# Avatar                                      Action|Adventure|Fantasy|Sci-Fi
# Pirates of the Caribbean: At World's End           Action|Adventure|Fantasy
# Spectre                                           Action|Adventure|Thriller
# The Dark Knight Rises                                       Action|Thriller
# Star Wars: Episode VII - The Force Awakens                      Documentary
#
#                                            num_reviews  num_voted_users  \
# title
# Avatar                                           723.0           886204
# Pirates of the Caribbean: At World's End         302.0           471220
# Spectre                                          602.0           275868
# The Dark Knight Rises                            813.0          1144337
# Star Wars: Episode VII - The Force Awakens         NaN                8
#
#                                                                                 plot_keywords  \
# title
# Avatar                                                 avatar|future|marine|native|paraplegic
# Pirates of the Caribbean: At World's End    goddess|marriage ceremony|marriage proposal|pi...
# Spectre                                                   bomb|espionage|sequel|spy|terrorist
# The Dark Knight Rises                       deception|imprisonment|lawlessness|police offi...
# Star Wars: Episode VII - The Force Awakens                                                NaN
#
#                                            language country       budget  \
# title
# Avatar                                      English     USA  237000000.0
# Pirates of the Caribbean: At World's End    English     USA  300000000.0
# Spectre                                     English      UK  245000000.0
# The Dark Knight Rises                       English     USA  250000000.0
# Star Wars: Episode VII - The Force Awakens      NaN     NaN          NaN
#
#                                             imdb_score
# title
# Avatar                                             7.9
# Pirates of the Caribbean: At World's End           7.1
# Spectre                                            6.8
# The Dark Knight Rises                              8.5
# Star Wars: Episode VII - The Force Awakens         7.1
#
# [5 rows x 21 columns]

# %%
filt = movies['actor2_fb'] > movies['actor1_fb']
movies[filt]
# Out:
# Empty DataFrame
# Columns: [year, color, content_rating, duration, director_name, director_fb, actor1, actor1_fb, actor2, actor2_fb, actor3, actor3_fb, gross, genres, num_reviews, num_voted_users, plot_keywords, language, country, budget, imdb_score]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# ### Problem 5
# <span  style="color:green; font-size:16px">Select the year, content rating, and IMDB score columns for movies from the year 2016 with IMDB score less than 4.</span>

# %%
# your code here
filt = movies['imdb_score'] < 4
cols = ['year', 'content_rating', 'imdb_score']
movies.loc[filt, cols].head()
# Out:
#                            year content_rating  imdb_score
# title
# Batman & Robin           1997.0          PG-13         3.7
# Speed 2: Cruise Control  1997.0          PG-13         3.7
# The Cat in the Hat       2003.0             PG         3.8
# Catwoman                 2004.0          PG-13         3.3
# Son of the Mask          2005.0             PG         2.2

# %% [markdown]
# ### Problem 6
# <span  style="color:green; font-size:16px">Select all the movies that are missing values for content rating.</span>

# %%
# your code here
filt = movies['content_rating'].isna()
movies[filt]
# Out:
#                                                  year            color  \
# title
# Star Wars: Episode VII - The Force Awakens        NaN              NaN
# Godzilla Resurgence                            2016.0            Color
# Harry Potter and the Deathly Hallows: Part II  2011.0            Color
# Harry Potter and the Deathly Hallows: Part I   2010.0            Color
# Asterix at the Olympic Games                   2008.0            Color
# 10,000 B.C.                                       NaN              NaN
# Evolution                                      2015.0            Color
# Life                                              NaN            Color
# The Missing                                       NaN            Color
# Xi you ji zhi: Sun Wukong san da Baigu Jing    2016.0            Color
# Anger Management                                  NaN            Color
# Unforgotten                                       NaN            Color
# A Touch of Frost                                  NaN            Color
# Twisted                                           NaN            Color
# The Tooth Fairy                                2006.0            Color
# Animal Kingdom: Let's go Ape                   2015.0            Color
# Baahubali: The Beginning                       2015.0            Color
# Dragon Nest: Warriors' Dawn                    2014.0            Color
# Obitaemyy ostrov                               2009.0            Color
# Hit the Floor                                     NaN            Color
# Black Water Transit                            2009.0            Color
# Thunder and the House of Magic                 2013.0            Color
# Trapped                                           NaN            Color
# Little Nicholas                                2009.0            Color
# Grace of Monaco                                2014.0            Color
# A Warrior's Tail                               2015.0            Color
# Captain Alatriste: The Spanish Musketeer       2006.0            Color
# The Honeymooners                                  NaN  Black and White
# The Magic Flute                                2006.0            Color
# Viy                                            2014.0            Color
# ...                                               ...              ...
# A Dog's Breakfast                              2007.0            Color
# Une Femme Mariée                               1964.0  Black and White
# The Work and the Story                         2003.0            Color
# Over the Hill to the Poorhouse                 1920.0  Black and White
# Echo Dr.                                       2013.0            Color
# Peace, Propaganda & the Promised Land          2004.0            Color
# Queen Crab                                     2015.0            Color
# The Naked Ape                                  2006.0            Color
# Counting                                       2015.0            Color
# The Call of Cthulhu                            2005.0  Black and White
# Bending Steel                                  2013.0            Color
# The Image Revolution                           2014.0            Color
# A True Story                                   2013.0            Color
# Dawn of the Crescent Moon                      2014.0            Color
# Run, Hide, Die                                 2012.0            Color
# Funny Ha Ha                                    2002.0            Color
# Manito                                         2002.0            Color
# Dutch Kills                                    2015.0            Color
# Dry Spell                                      2013.0            Color
# Flywheel                                       2003.0            Color
# The Ridges                                     2011.0              NaN
# Stories of Our Lives                           2014.0  Black and White
# Breaking Upwards                               2009.0            Color
# Tin Can Man                                    2007.0  Black and White
# The Cure                                       1997.0            Color
# On the Downlow                                 2004.0            Color
# Sanctuary; Quite a Conundrum                   2012.0            Color
# Bang                                           1995.0            Color
# Signed Sealed Delivered                        2013.0            Color
# A Plague So Pleasant                           2013.0            Color
#
#                                               content_rating  duration  \
# title
# Star Wars: Episode VII - The Force Awakens               NaN       NaN
# Godzilla Resurgence                                      NaN     120.0
# Harry Potter and the Deathly Hallows: Part II            NaN       NaN
# Harry Potter and the Deathly Hallows: Part I             NaN       NaN
# Asterix at the Olympic Games                             NaN     116.0
# 10,000 B.C.                                              NaN      22.0
# Evolution                                                NaN      81.0
# Life                                                     NaN      45.0
# The Missing                                              NaN      60.0
# Xi you ji zhi: Sun Wukong san da Baigu Jing              NaN     119.0
# Anger Management                                         NaN      22.0
# Unforgotten                                              NaN      45.0
# A Touch of Frost                                         NaN     105.0
# Twisted                                                  NaN      60.0
# The Tooth Fairy                                          NaN      89.0
# Animal Kingdom: Let's go Ape                             NaN     101.0
# Baahubali: The Beginning                                 NaN     159.0
# Dragon Nest: Warriors' Dawn                              NaN      88.0
# Obitaemyy ostrov                                         NaN     115.0
# Hit the Floor                                            NaN      60.0
# Black Water Transit                                      NaN       NaN
# Thunder and the House of Magic                           NaN      85.0
# Trapped                                                  NaN     511.0
# Little Nicholas                                          NaN      91.0
# Grace of Monaco                                          NaN     103.0
# A Warrior's Tail                                         NaN      85.0
# Captain Alatriste: The Spanish Musketeer                 NaN     145.0
# The Honeymooners                                         NaN      30.0
# The Magic Flute                                          NaN     135.0
# Viy                                                      NaN     107.0
# ...                                                      ...       ...
# A Dog's Breakfast                                        NaN      88.0
# Une Femme Mariée                                         NaN      94.0
# The Work and the Story                                   NaN      77.0
# Over the Hill to the Poorhouse                           NaN     110.0
# Echo Dr.                                                 NaN      81.0
# Peace, Propaganda & the Promised Land                    NaN      80.0
# Queen Crab                                               NaN      80.0
# The Naked Ape                                            NaN       NaN
# Counting                                                 NaN     111.0
# The Call of Cthulhu                                      NaN      47.0
# Bending Steel                                            NaN      92.0
# The Image Revolution                                     NaN      81.0
# A True Story                                             NaN      96.0
# Dawn of the Crescent Moon                                NaN      95.0
# Run, Hide, Die                                           NaN      75.0
# Funny Ha Ha                                              NaN      85.0
# Manito                                                   NaN      79.0
# Dutch Kills                                              NaN      90.0
# Dry Spell                                                NaN      90.0
# Flywheel                                                 NaN     120.0
# The Ridges                                               NaN     143.0
# Stories of Our Lives                                     NaN      60.0
# Breaking Upwards                                         NaN      88.0
# Tin Can Man                                              NaN      83.0
# The Cure                                                 NaN     111.0
# On the Downlow                                           NaN      84.0
# Sanctuary; Quite a Conundrum                             NaN      82.0
# Bang                                                     NaN      98.0
# Signed Sealed Delivered                                  NaN      87.0
# A Plague So Pleasant                                     NaN      76.0
#
#                                                        director_name  \
# title
# Star Wars: Episode VII - The Force Awakens               Doug Walker
# Godzilla Resurgence                                106.0     ...
# Harry Potter and the Deathly Hallows: Part II      570.0     ...
# Harry Potter and the Deathly Hallows: Part I      2000.0     ...
# Asterix at the Olympic Games                       276.0     ...
# 10,000 B.C.                                          NaN     ...
# Evolution                                           21.0     ...
# Life                                               130.0     ...
# The Missing                                        773.0     ...
# Xi you ji zhi: Sun Wukong san da Baigu Jing        107.0     ...
# Anger Management                                   701.0     ...
# Unforgotten                                        171.0     ...
# A Touch of Frost                                     7.0     ...
# Twisted                                            512.0     ...
# The Tooth Fairy                                    555.0     ...
# Animal Kingdom: Let's go Ape                       152.0     ...
# Baahubali: The Beginning                           133.0     ...
# Dragon Nest: Warriors' Dawn                         47.0     ...
# Obitaemyy ostrov                                    35.0     ...
# Hit the Floor                                      637.0     ...
# Black Water Transit                                856.0     ...
# Thunder and the House of Magic                      15.0     ...
# Trapped                                             63.0     ...
# Little Nicholas                                     71.0     ...
# Grace of Monaco                                    903.0     ...
# A Warrior's Tail                                    35.0     ...
# Captain Alatriste: The Spanish Musketeer          1000.0     ...
# The Honeymooners                                   154.0     ...
# The Magic Flute                                      4.0     ...
# Viy                                                 65.0     ...
# ...                                                  ...     ...
# A Dog's Breakfast                                  686.0     ...
# Une Femme Mariée                                     7.0     ...
# The Work and the Story                              81.0     ...
# Over the Hill to the Poorhouse                       2.0     ...
# Echo Dr.                                            18.0     ...
# Peace, Propaganda & the Promised Land                0.0     ...
# Queen Crab                                          15.0     ...
# The Naked Ape                                       36.0     ...
# Counting                                             NaN     ...
# The Call of Cthulhu                                  9.0     ...
# Bending Steel                                        NaN     ...
# The Image Revolution                                20.0     ...
# A True Story                                       482.0     ...
# Dawn of the Crescent Moon                          507.0     ...
# Run, Hide, Die                                     132.0     ...
# Funny Ha Ha                                          6.0     ...
# Manito                                              46.0     ...
# Dutch Kills                                         25.0     ...
# Dry Spell                                          184.0     ...
# Flywheel                                            49.0     ...
# The Ridges                                          19.0     ...
# Stories of Our Lives                                19.0     ...
# Breaking Upwards                                   212.0     ...
# Tin Can Man                                          5.0     ...
# The Cure                                            13.0     ...
# On the Downlow                                      20.0     ...
# Sanctuary; Quite a Conundrum                        98.0     ...
# Bang                                               194.0     ...
# Signed Sealed Delivered                            470.0     ...
# A Plague So Pleasant                                 0.0     ...
#
#                                               actor3_fb      gross  \
# title
# Star Wars: Episode VII - The Force Awakens          NaN        NaN
# Godzilla Resurgence                                12.0        NaN
# Harry Potter and the Deathly Hallows: Part II     159.0        NaN
# Harry Potter and the Deathly Hallows: Part I     1000.0        NaN
# Asterix at the Olympic Games                      141.0        NaN
# 10,000 B.C.                                         NaN        NaN
# Evolution                                           8.0        NaN
# Life                                                0.0        NaN
# The Missing                                       575.0        NaN
# Xi you ji zhi: Sun Wukong san da Baigu Jing        22.0        NaN
# Anger Management                                  676.0        NaN
# Unforgotten                                       132.0        NaN
# A Touch of Frost                                    5.0        NaN
# Twisted                                           398.0        NaN
# The Tooth Fairy                                   235.0        NaN
# Animal Kingdom: Let's go Ape                        6.0        NaN
# Baahubali: The Beginning                           72.0  6498000.0
# Dragon Nest: Warriors' Dawn                        46.0        NaN
# Obitaemyy ostrov                                   30.0        NaN
# Hit the Floor                                     628.0        NaN
# Black Water Transit                               816.0        NaN
# Thunder and the House of Magic                     11.0     4091.0
# Trapped                                            51.0        NaN
# Little Nicholas                                    55.0        NaN
# Grace of Monaco                                   520.0        NaN
# A Warrior's Tail                                   21.0        NaN
# Captain Alatriste: The Spanish Musketeer          278.0        NaN
# The Honeymooners                                   94.0        NaN
# The Magic Flute                                     3.0        NaN
# Viy                                                48.0        NaN
# ...                                                 ...        ...
# A Dog's Breakfast                                 405.0        NaN
# Une Femme Mariée                                    5.0        NaN
# The Work and the Story                             69.0        NaN
# Over the Hill to the Poorhouse                      0.0  3000000.0
# Echo Dr.                                           10.0        NaN
# Peace, Propaganda & the Promised Land               0.0        NaN
# Queen Crab                                          3.0        NaN
# The Naked Ape                                      15.0        NaN
# Counting                                            NaN        NaN
# The Call of Cthulhu                                 5.0        NaN
# Bending Steel                                       NaN        NaN
# The Image Revolution                               18.0        NaN
# A True Story                                      281.0        NaN
# Dawn of the Crescent Moon                         279.0        NaN
# Run, Hide, Die                                    130.0        NaN
# Funny Ha Ha                                         3.0        NaN
# Manito                                             42.0        NaN
# Dutch Kills                                         9.0        NaN
# Dry Spell                                         138.0        NaN
# Flywheel                                            4.0        NaN
# The Ridges                                          8.0        NaN
# Stories of Our Lives                                4.0        NaN
# Breaking Upwards                                  211.0    76382.0
# Tin Can Man                                         0.0        NaN
# The Cure                                            6.0    94596.0
# On the Downlow                                     12.0        NaN
# Sanctuary; Quite a Conundrum                       84.0        NaN
# Bang                                              152.0        NaN
# Signed Sealed Delivered                           318.0        NaN
# A Plague So Pleasant                                0.0        NaN
#
#                                                                                      genres  \
# title
# Star Wars: Episode VII - The Force Awakens                                      Documentary
# Godzilla Resurgence                                    Action|Adventure|Drama|Horror|Sci-Fi
# Harry Potter and the Deathly Hallows: Part II                                Action|Fantasy
# Harry Potter and the Deathly Hallows: Part I                                        Fantasy
# Asterix at the Olympic Games                                Adventure|Comedy|Family|Fantasy
# 10,000 B.C.                                                                          Comedy
# Evolution                                                       Drama|Horror|Mystery|Sci-Fi
# Life                                                                    Crime|Drama|Mystery
# The Missing                                                             Crime|Drama|Mystery
# Xi you ji zhi: Sun Wukong san da Baigu Jing                        Action|Adventure|Fantasy
# Anger Management                                                             Comedy|Romance
# Unforgotten                                                                     Crime|Drama
# A Touch of Frost                                                        Crime|Drama|Mystery
# Twisted                                                              Drama|Mystery|Thriller
# The Tooth Fairy                                                             Horror|Thriller
# Animal Kingdom: Let's go Ape                              Adventure|Animation|Comedy|Family
# Baahubali: The Beginning                                 Action|Adventure|Drama|Fantasy|War
# Dragon Nest: Warriors' Dawn                              Adventure|Animation|Family|Fantasy
# Obitaemyy ostrov                                                    Action|Adventure|Sci-Fi
# Hit the Floor                                                                 Drama|Romance
# Black Water Transit                                                             Crime|Drama
# Thunder and the House of Magic                    Adventure|Animation|Comedy|Family|Fantasy
# Trapped                                                                Crime|Drama|Thriller
# Little Nicholas                                                               Comedy|Family
# Grace of Monaco                                                     Biography|Drama|Romance
# A Warrior's Tail                                                Adventure|Animation|Fantasy
# Captain Alatriste: The Spanish Musketeer       Adventure|Drama|History|Romance|Thriller|War
# The Honeymooners                                                              Comedy|Family
# The Magic Flute                                                       Drama|Musical|Romance
# Viy                                                      Adventure|Fantasy|Mystery|Thriller
# ...                                                                                     ...
# A Dog's Breakfast                                                                    Comedy
# Une Femme Mariée                                                                      Drama
# The Work and the Story                                                               Comedy
# Over the Hill to the Poorhouse                                                  Crime|Drama
# Echo Dr.                                                       Action|Drama|Sci-Fi|Thriller
# Peace, Propaganda & the Promised Land                                           Documentary
# Queen Crab                                                           Action|Sci-Fi|Thriller
# The Naked Ape                                                                  Comedy|Drama
# Counting                                                                        Documentary
# The Call of Cthulhu                                         Fantasy|Horror|Mystery|Thriller
# Bending Steel                                                                   Documentary
# The Image Revolution                                                  Biography|Documentary
# A True Story                                                                         Comedy
# Dawn of the Crescent Moon                                             Drama|Sci-Fi|Thriller
# Run, Hide, Die                                                              Horror|Thriller
# Funny Ha Ha                                                                    Comedy|Drama
# Manito                                                                         Drama|Family
# Dutch Kills                                                            Crime|Drama|Thriller
# Dry Spell                                                                    Comedy|Romance
# Flywheel                                                                              Drama
# The Ridges                                                            Drama|Horror|Thriller
# Stories of Our Lives                                                                  Drama
# Breaking Upwards                                                                    Romance
# Tin Can Man                                                                          Horror
# The Cure                                                      Crime|Horror|Mystery|Thriller
# On the Downlow                                                                        Drama
# Sanctuary; Quite a Conundrum                                         Comedy|Horror|Thriller
# Bang                                                                            Crime|Drama
# Signed Sealed Delivered                                                        Comedy|Drama
# A Plague So Pleasant                                                  Drama|Horror|Thriller
#
#                                               num_reviews  num_voted_users  \
# title
# Star Wars: Episode VII - The Force Awakens            NaN                8
# Godzilla Resurgence                                   1.0              374
# Harry Potter and the Deathly Hallows: Part II         1.0              381
# Harry Potter and the Deathly Hallows: Part I          4.0              252
# Asterix at the Olympic Games                         33.0            20567
# 10,000 B.C.                                           NaN                6
# Evolution                                            63.0              979
# Life                                                 12.0            29450
# The Missing                                          14.0             8739
# Xi you ji zhi: Sun Wukong san da Baigu Jing          14.0             1212
# Anger Management                                     26.0            26992
# Unforgotten                                           2.0             1824
# A Touch of Frost                                     14.0             4438
# Twisted                                               4.0             7945
# The Tooth Fairy                                      32.0             1263
# Animal Kingdom: Let's go Ape                          9.0              590
# Baahubali: The Beginning                             44.0            62756
# Dragon Nest: Warriors' Dawn                           4.0             2169
# Obitaemyy ostrov                                     14.0             4387
# Hit the Floor                                         3.0             1641
# Black Water Transit                                   NaN              219
# Thunder and the House of Magic                       60.0             4265
# Trapped                                              16.0             2308
# Little Nicholas                                      56.0             9214
# Grace of Monaco                                     132.0            12410
# A Warrior's Tail                                      5.0              393
# ...
# The Cure                                             78.0             6318
# On the Downlow                                        NaN              156
# Sanctuary; Quite a Conundrum                         13.0              133
# Bang                                                 10.0              438
# Signed Sealed Delivered                               1.0              629
# A Plague So Pleasant                                 13.0               38
#
#                                                                                    plot_keywords  \
# title
# Star Wars: Episode VII - The Force Awakens                                                   NaN
# Godzilla Resurgence                                                blood|godzilla|monster|sequel
# Harry Potter and the Deathly Hallows: Part II                                                NaN
# Harry Potter and the Deathly Hallows: Part I                                                 NaN
# Asterix at the Olympic Games                   1st century b.c.|lightsaber|local blockbuster|...
# 10,000 B.C.                                                                                  NaN
# Evolution                                             boy|giving birth|nurse|sea|ultrasonography
# Life                                                   cop|murder|partner|police|protective male
# The Missing                                     france|journalist|limp|police detective|reporter
# Xi you ji zhi: Sun Wukong san da Baigu Jing    buddhism|demon|journey to the west|monk|monkey...
# Anger Management                               anger management|argument|irony|sarcasm|therapist
# Unforgotten                                                                                  NaN
# A Touch of Frost                               cult tv|death|detective inspector|four word ti...
# Twisted                                                                                      NaN
# The Tooth Fairy                                bare breasts|genital dismemberment|mulching so...
# Animal Kingdom: Let's go Ape                   ape|computer animation|evolution|first person ...
# Baahubali: The Beginning                       ancient india|dual role|good versus evil|hindu...
# Dragon Nest: Warriors' Dawn                                                                  NaN
# Obitaemyy ostrov                                22nd century|first part|friend|guard|space opera
# Hit the Floor                                                           affair|hip hop|sex scene
# Black Water Transit                                                               based on novel
# Thunder and the House of Magic                                                               NaN
# Trapped                                        coastal town|iceland|police|snowstorm|winter s...
# Little Nicholas                                baby|dinner|family relationships|school|three ...
# Grace of Monaco                                   1960s|grace kelly|hollywood star|monaco|prince
# A Warrior's Tail                                            battle|creature|hyena|monkey|village
# Captain Alatriste: The Spanish Musketeer                         desire|fighting|king|spain|trap
# The Honeymooners                                     1950s|bus driver|money scheme|poverty|sewer
# The Magic Flute                                 based on opera|evil|mozart|queen|walking wounded
# Viy                                            cartographer|creature|foreign language adaptat...
# ...                                                                                          ...
# A Dog's Breakfast                                                                 dog|vegetarian
# Une Femme Mariée                                         acting|actor|face slap|fashion|magazine
# The Work and the Story                         latter day saints|lds film|mock documentary|mo...
# Over the Hill to the Poorhouse                   family relationships|gang|idler|poorhouse|thief
# Echo Dr.                                       android|artificial intelligence|home invasion|...
# Peace, Propaganda & the Promised Land          arab israeli conflict|israel|media|middle east...
# Queen Crab                                                                                   NaN
# The Naked Ape                                  coming of age|male nudity|road trip|skinny dip...
# Counting                                             city|city symphony|diary|essay|surveillance
# The Call of Cthulhu                                       1920s|cthulhu|dream|sailor|silent film
# Bending Steel                                                                                NaN
# The Image Revolution                           comic book|comic book history|comics|spawn|wal...
# A True Story                                   ellipsis in title|long title|period in title|p...
# Dawn of the Crescent Moon                                                                    NaN
# Run, Hide, Die                                                                               NaN
# Funny Ha Ha                                                                           mumblecore
# Manito                                         ex convict|graduation|manhattan new york city|...
# Dutch Kills                                                                                  NaN
# Dry Spell                                      anti romantic comedy|dating|divorce|sex comedy...
# Flywheel                                       baby|car salesman|christian film|pregnancy|use...
# The Ridges                                                  avatar|college|death|tron|university
# 10,000 B.C.                                           NaN         7.2
# Evolution                                             NaN         6.4
# Life                                                  NaN         8.3
# The Missing                                           NaN         8.1
# Xi you ji zhi: Sun Wukong san da Baigu Jing    68005000.0         6.0
# Anger Management                                      NaN         6.7
# Unforgotten                                           NaN         7.9
# A Touch of Frost                                      NaN         7.8
# Twisted                                               NaN         7.5
# The Tooth Fairy                                 1500000.0         4.6
# Animal Kingdom: Let's go Ape                          NaN         4.9
# Baahubali: The Beginning                       18026148.0         8.4
# Dragon Nest: Warriors' Dawn                    40000000.0         6.4
# Obitaemyy ostrov                               29500000.0         5.3
# Hit the Floor                                         NaN         7.0
# Black Water Transit                            23000000.0         7.2
# Thunder and the House of Magic                 34000000.0         6.3
# Trapped                                               NaN         8.2
# Little Nicholas                                       NaN         7.2
# Grace of Monaco                                30000000.0         5.7
# A Warrior's Tail                               30000000.0         4.1
# Captain Alatriste: The Spanish Musketeer       24000000.0         6.1
# The Honeymooners                                      NaN         8.7
# The Magic Flute                                27000000.0         6.6
# Viy                                            26000000.0         5.4
# ...                                                   ...         ...
# A Dog's Breakfast                                120000.0         7.0
# Une Femme Mariée                                 120000.0         7.4
# The Work and the Story                           103000.0         5.7
# Over the Hill to the Poorhouse                   100000.0         4.8
# Echo Dr.                                         100000.0         3.6
# Peace, Propaganda & the Promised Land             70000.0         8.3
# Queen Crab                                        75000.0         4.5
# The Naked Ape                                         NaN         4.7
# Counting                                          50000.0         6.0
# The Call of Cthulhu                               50000.0         7.3
# Bending Steel                                     50000.0         7.9
# The Image Revolution                              50000.0         7.4
# A True Story                                      45000.0         5.5
# Dawn of the Crescent Moon                         75000.0         5.0
# Run, Hide, Die                                    50000.0         3.7
# Funny Ha Ha                                           NaN         6.4
# Manito                                            24000.0         7.0
# Dutch Kills                                       25000.0         4.8
# Dry Spell                                         22000.0         3.3
# Flywheel                                          20000.0         6.9
# The Ridges                                        17350.0         3.0
# Stories of Our Lives                              15000.0         7.4
# Breaking Upwards                                  15000.0         6.2
# Tin Can Man                                       10000.0         6.7
# The Cure                                        1000000.0         7.4
# On the Downlow                                        NaN         6.1
# Sanctuary; Quite a Conundrum                     200000.0         5.4
# Bang                                                  NaN         6.4
# Signed Sealed Delivered                               NaN         7.7
# A Plague So Pleasant                               1400.0         6.3
#
# [300 rows x 21 columns]

# %% [markdown]
# ### Problem 7
# <span  style="color:green; font-size:16px">Select all the movies that are missing both the gross and budget. Return just those columns to verify that those values are indeed missing.</span>

# %%
# your code here
filt1 = movies['gross'].isna()
filt2 = movies['budget'].isna()
filt = filt1 & filt2 
movies[filt]
# Out:
#                                                  year            color  \
# title
# Star Wars: Episode VII - The Force Awakens        NaN              NaN
# The Lovers                                     2015.0            Color
# Godzilla Resurgence                            2016.0            Color
# Harry Potter and the Deathly Hallows: Part II  2011.0            Color
# Harry Potter and the Deathly Hallows: Part I   2010.0            Color
# The A-Team                                        NaN            Color
# 10,000 B.C.                                       NaN              NaN
# Ben-Hur                                        2016.0            Color
# Hannibal                                          NaN            Color
# All That Jazz                                  1979.0            Color
# Daredevil                                         NaN              NaN
# Bewitched                                         NaN  Black and White
# Evolution                                      2015.0            Color
# Constantine                                       NaN            Color
# Life                                              NaN            Color
# Sleepy Hollow                                     NaN            Color
# Last Man Standing                                 NaN            Color
# The Missing                                       NaN            Color
# Rules of Engagement                               NaN            Color
# The Ridiculous 6                               2015.0            Color
# Sex and the City                                  NaN            Color
# Anger Management                                  NaN            Color
# Unforgotten                                       NaN            Color
# A Touch of Frost                                  NaN            Color
# Twisted                                           NaN            Color
# Defiance                                          NaN            Color
# Outlander                                         NaN            Color
# The Returned                                      NaN            Color
# McHale's Navy                                     NaN  Black and White
# Animal Kingdom: Let's go Ape                   2015.0            Color
# ...                                               ...              ...
# Home Movies                                       NaN            Color
# Revolution                                        NaN            Color
# The Big Swap                                   1998.0            Color
# Midnight Cabaret                               1990.0              NaN
# Happy Valley                                      NaN            Color
# On the Outs                                    2004.0            Color
# Exam                                           2009.0            Color
# Sunday School Musical                          2008.0            Color
# Ink                                            2009.0            Color
# Jesus People                                   2007.0            Color
# Butterfly                                      1982.0            Color
# Solitude                                       2014.0            Color
# Ordet                                          1955.0  Black and White
# H.                                             2014.0            Color
# When the Lights Went Out                       2012.0            Color
# Heroes of Dirt                                 2015.0            Color
# Open Secret                                    1948.0  Black and White
# The Night Visitor                              1971.0            Color
# Supporting Characters                          2012.0            Color
# The Dirties                                    2013.0            Color
# Gabriela                                       1983.0            Color
# The Naked Ape                                  2006.0            Color
# Mutual Appreciation                            2005.0  Black and White
# Funny Ha Ha                                    2002.0            Color
# Rampage                                        2009.0            Color
# Exeter                                         2015.0            Color
# On the Downlow                                 2004.0            Color
# Bang                                           1995.0            Color
# Signed Sealed Delivered                        2013.0            Color
# The Following                                     NaN            Color
#
#                                               content_rating  duration  \
# title
# Star Wars: Episode VII - The Force Awakens               NaN       NaN
# The Lovers                                                 R     109.0
# Godzilla Resurgence                                      NaN     120.0
# Harry Potter and the Deathly Hallows: Part II            NaN       NaN
# Harry Potter and the Deathly Hallows: Part I             NaN       NaN
# The A-Team                                             TV-PG      60.0
# 10,000 B.C.                                              NaN      22.0
# Ben-Hur                                                PG-13     141.0
# Hannibal                                               TV-14      44.0
# All That Jazz                                              R     123.0
# Daredevil                                              TV-MA      54.0
# Bewitched                                               TV-G      25.0
# Evolution                                                NaN      81.0
# Constantine                                            TV-14      43.0
# Life                                                     NaN      45.0
# Sleepy Hollow                                          TV-14      45.0
# Last Man Standing                                      TV-PG      30.0
# The Missing                                              NaN      60.0
# Rules of Engagement                                    TV-PG      22.0
# The Ridiculous 6                                       TV-14     119.0
# Sex and the City                                       TV-MA      30.0
# Anger Management                                         NaN      22.0
# Unforgotten                                              NaN      45.0
# A Touch of Frost                                         NaN     105.0
# Twisted                                                  NaN      60.0
# Defiance                                               TV-MA      43.0
# Outlander                                              TV-MA      64.0
# The Returned                                           TV-MA      52.0
# McHale's Navy                                           TV-G      30.0
# Animal Kingdom: Let's go Ape                             NaN     101.0
# ...                                                      ...       ...
# Home Movies                                            TV-PG      22.0
# Revolution                                             TV-14      43.0
# The Big Swap                                             NaN     114.0
# Midnight Cabaret                                           R      94.0
# Happy Valley                                           TV-MA      58.0
# On the Outs                                                R      86.0
# Exam                                               Not Rated     101.0
# Sunday School Musical                                      G      93.0
# Ink                                                      NaN     107.0
# Jesus People                                             NaN      35.0
# Butterfly                                                  R     108.0
# Solitude                                                 NaN      89.0
# Ordet                                              Not Rated     126.0
# H.                                                       NaN      93.0
# When the Lights Went Out                                 NaN      86.0
# Heroes of Dirt                                         PG-13      98.0
# Open Secret                                         Approved      68.0
# The Night Visitor                                         GP     106.0
# Supporting Characters                              Not Rated      87.0
# The Dirties                                        Not Rated      83.0
# Gabriela                                                   R      99.0
# The Naked Ape                                            NaN       NaN
# Mutual Appreciation                                        R     109.0
# Funny Ha Ha                                              NaN      85.0
# Rampage                                                    R      80.0
# Exeter                                                     R      91.0
# On the Downlow                                           NaN      84.0
# Bang                                                     NaN      98.0
# Signed Sealed Delivered                                  NaN      87.0
# The Following                                          TV-14      43.0
#
#                                                        director_name  \
# title
# Star Wars: Episode VII - The Force Awakens               Doug Walker
# The Lovers                                              Roland Joffé
# Godzilla Resurgence                                     Hideaki Anno
# Harry Potter and the Deathly Hallows: Part II             Matt Birch
# Harry Potter and the Deathly Hallows: Part I              Matt Birch
# The A-Team                                                       NaN
# 10,000 B.C.                                      Christopher Barnard
# Ben-Hur                                            Timur Bekmambetov
# Hannibal                                                         NaN
# All That Jazz                                              Bob Fosse
# Daredevil                                                        NaN
# Bewitched                                                        NaN
# Evolution                                      Lucile Hadzihalilovic
# Constantine                                                      NaN
# Life                                                             NaN
# Sleepy Hollow                                                    NaN
# Last Man Standing                                                NaN
# The Missing                                                      NaN
# Rules of Engagement                                              NaN
# The Ridiculous 6                                        Frank Coraci
# Sex and the City                                                 NaN
# Anger Management                                                 NaN
# Unforgotten                                                      NaN
# A Touch of Frost                                                 NaN
# Twisted                                                          NaN
# Defiance                                                         NaN
# Outlander                                                        NaN
# The Returned                                                     NaN
# McHale's Navy                                                    NaN
# Animal Kingdom: Let's go Ape                          Jamel Debbouze
# ...                                                              ...
# Home Movies                                                      NaN
# Revolution                                                       NaN
# The Big Swap                                           Niall Johnson
# Midnight Cabaret                                          Pece Dingo
# Happy Valley                                                     NaN
# On the Outs                                          Lori Silverbush
# Exam                                                Stuart Hazeldine
# Sunday School Musical                              Rachel Goldenberg
# Ink                                                     Jamin Winans
# Jesus People                                           Jason Naumann
# Butterfly                                                Matt Cimber
# Solitude                                             Livingston Oden
# Ordet                                            Carl Theodor Dreyer
# H.                                                      Rania Attieh
# When the Lights Went Out                                  Pat Holden
# Heroes of Dirt                                           Eric Bugbee
# Open Secret                                           John Reinhardt
# The Night Visitor                                      Laslo Benedek
# Supporting Characters                               Daniel Schechter
# The Dirties                                             Matt Johnson
# Gabriela                                               Bruno Barreto
# The Naked Ape                                         Daniel Mellitz
# Mutual Appreciation                                  Andrew Bujalski
# Funny Ha Ha                                          Andrew Bujalski
# Rampage                                                     Uwe Boll
# Exeter                                                 Marcus Nispel
# On the Downlow                                          Tadeo Garcia
# Bang                                                 Ash Baron-Cohen
# Signed Sealed Delivered                                  Scott Smith
# The Following                                                    NaN
#
#                                                director_fb  \
# title
# Star Wars: Episode VII - The Force Awakens           131.0
# The Lovers                                           596.0
# Godzilla Resurgence                                   28.0
# Harry Potter and the Deathly Hallows: Part II          0.0
# Harry Potter and the Deathly Hallows: Part I           0.0
# The A-Team                                             NaN
# 10,000 B.C.                                            0.0
# Ben-Hur                                              335.0
# Hannibal                                               NaN
# All That Jazz                                        189.0
# Daredevil                                              NaN
# Bewitched                                              NaN
# Evolution                                             92.0
# Constantine                                            NaN
# Life                                                   NaN
# Sleepy Hollow                                          NaN
# Last Man Standing                                      NaN
# The Missing                                            NaN
# Rules of Engagement                                    NaN
# The Ridiculous 6                                     153.0
# Sex and the City                                       NaN
# Anger Management                                       NaN
# Unforgotten                                            NaN
# A Touch of Frost                                       NaN
# Twisted                                                NaN
# Defiance                                               NaN
# Outlander                                              NaN
# The Returned                                           NaN
# McHale's Navy                                          NaN
# Animal Kingdom: Let's go Ape                         326.0
# ...                                                    ...
# Home Movies                                            NaN
# Revolution                                             NaN
# The Big Swap                                           7.0
# Midnight Cabaret                                       0.0
# Happy Valley                                           NaN
# On the Outs                                            5.0
# Exam                                                  17.0
# Sunday School Musical                                  7.0
# Ink                                                   63.0
# Jesus People                                           2.0
# Butterfly                                             32.0
# Solitude                                               0.0
# Ordet                                                147.0
# H.                                                     0.0
# When the Lights Went Out                               6.0
# Heroes of Dirt                                         0.0
# Open Secret                                            2.0
# The Night Visitor                                      6.0
# Supporting Characters                                  8.0
# The Dirties                                            8.0
# Gabriela                                               9.0
# The Naked Ape                                          0.0
# Mutual Appreciation                                   26.0
# Funny Ha Ha                                           26.0
# Rampage                                              892.0
# Exeter                                               158.0
# On the Downlow                                         5.0
# Bang                                                   3.0
# Signed Sealed Delivered                                2.0
# The Following                                          NaN
#
#                                                              actor1  \
# title
# Star Wars: Episode VII - The Force Awakens              Doug Walker
# The Lovers                                           Tamsin Egerton
# Godzilla Resurgence                                   Mark Chinnery
# Harry Potter and the Deathly Hallows: Part II          Rupert Grint
# Harry Potter and the Deathly Hallows: Part I           Rupert Grint
# The A-Team                                           George Peppard
# 10,000 B.C.                                             Mathew Buck
# Ben-Hur                                              Morgan Freeman
# Hannibal                                         Caroline Dhavernas
# All That Jazz                                          Roy Scheider
# Daredevil                                              Elden Henson
# Bewitched                                      Elizabeth Montgomery
# Evolution                                             Nissim Renard
# Constantine                                        Harold Perrineau
# Life                                                     Adam Arkin
# Sleepy Hollow                                        Nicole Beharie
# Last Man Standing                                   Hector Elizondo
# The Missing                                           Jason Flemyng
# Rules of Engagement                                  Bianca Kajlich
# The Ridiculous 6                                     Taylor Lautner
# Sex and the City                                         Chris Noth
# Anger Management                                       Barry Corbin
# The Big Swap                                        19.0           Mark Caven
# Midnight Cabaret                                   156.0  Wilhelm von Homburg
# Happy Valley                                       887.0         James Norton
# On the Outs                                         68.0         Flaco Navaja
# Exam                                               766.0           Luke Mably
# Sunday School Musical                              349.0          Mark Hengst
# Ink                                                135.0        Marty Lindsey
# Jesus People                                       338.0        Kate Flannery
# Butterfly                                          602.0        June Lockhart
# Solitude                                           138.0    Victoria Lachelle
# Ordet                                                0.0     Sylvia Eckhausen
# H.                                                 110.0       Robin Bartlett
# When the Lights Went Out                           498.0      Martin Compston
# Heroes of Dirt                                      52.0           Bill Allen
# Open Secret                                        142.0         John Ireland
# The Night Visitor                                  440.0        Trevor Howard
# Supporting Characters                              969.0       Kevin Corrigan
# The Dirties                                        111.0     Shailene Garnett
# Gabriela                                           866.0          Sonia Braga
# The Naked Ape                                     1000.0         Chelse Swain
# Mutual Appreciation                                 26.0     Kate Dollenmayer
# Funny Ha Ha                                         26.0     Kate Dollenmayer
# Rampage                                            986.0   Katharine Isabelle
# Exeter                                             630.0      Brittany Curran
# On the Downlow                                      21.0       Michael Cortez
# Bang                                               789.0    Stanley B. Herman
# Signed Sealed Delivered                            637.0        Daphne Zuniga
# The Following                                      841.0        Valorie Curry
#
#                                                actor2_fb     ...      \
# title                                                        ...
# Star Wars: Episode VII - The Force Awakens          12.0     ...
# The Lovers                                         525.0     ...
# Godzilla Resurgence                                106.0     ...
# Harry Potter and the Deathly Hallows: Part II      570.0     ...
# Harry Potter and the Deathly Hallows: Part I      2000.0     ...
# The A-Team                                         554.0     ...
# 10,000 B.C.                                          NaN     ...
# Ben-Hur                                            745.0     ...
# Hannibal                                           183.0     ...
# All That Jazz                                      388.0     ...
# Daredevil                                            4.0     ...
# Bewitched                                          960.0     ...
# Evolution                                           21.0     ...
# Constantine                                        560.0     ...
# Life                                               130.0     ...
# Sleepy Hollow                                      372.0     ...
# Last Man Standing                                  363.0     ...
# The Missing                                        773.0     ...
# Rules of Engagement                                607.0     ...
# The Ridiculous 6                                 11000.0     ...
# Sex and the City                                   722.0     ...
# Anger Management                                   701.0     ...
# Unforgotten                                        171.0     ...
# A Touch of Frost                                     7.0     ...
# Twisted                                            512.0     ...
# Defiance                                           845.0     ...
# Outlander                                          531.0     ...
# The Returned                                       116.0     ...
# McHale's Navy                                      284.0     ...
# Animal Kingdom: Let's go Ape                       152.0     ...
# ...                                                  ...     ...
# Home Movies                                         11.0     ...
# Revolution                                         821.0     ...
# The Big Swap                                        16.0     ...
# Midnight Cabaret                                   102.0     ...
# Happy Valley                                       340.0     ...
# On the Outs                                         64.0     ...
# Exam                                               438.0     ...
# Sunday School Musical                              168.0     ...
# Ink                                                115.0     ...
# Jesus People                                       219.0     ...
# Butterfly                                          427.0     ...
# Solitude                                            18.0     ...
# Ordet                                                0.0     ...
# H.                                                  79.0     ...
# When the Lights Went Out                           204.0     ...
# Heroes of Dirt                                      36.0     ...
# Open Secret                                         86.0     ...
# The Night Visitor                                   98.0     ...
# Supporting Characters                              778.0     ...
# The Dirties                                         19.0     ...
# Gabriela                                           308.0     ...
# The Naked Ape                                       36.0     ...
# Mutual Appreciation                                  6.0     ...
# Funny Ha Ha                                          6.0     ...
# Rampage                                            918.0     ...
# Exeter                                             512.0     ...
# On the Downlow                                      20.0     ...
# Bang                                               194.0     ...
# Signed Sealed Delivered                            470.0     ...
# The Following                                      593.0     ...
#
#                                               actor3_fb  gross  \
# title
# Star Wars: Episode VII - The Force Awakens          NaN    NaN
# The Lovers                                        283.0    NaN
# Godzilla Resurgence                                12.0    NaN
# Harry Potter and the Deathly Hallows: Part II     159.0    NaN
# Harry Potter and the Deathly Hallows: Part I     1000.0    NaN
# The A-Team                                        432.0    NaN
# 10,000 B.C.                                         NaN    NaN
# Ben-Hur                                           635.0    NaN
# Hannibal                                          148.0    NaN
# All That Jazz                                      87.0    NaN
# Daredevil                                           0.0    NaN
# Bewitched                                         474.0    NaN
# Evolution                                           8.0    NaN
# Constantine                                       218.0    NaN
# Life                                                0.0    NaN
# Sleepy Hollow                                     160.0    NaN
# Last Man Standing                                 359.0    NaN
# The Missing                                       575.0    NaN
# Rules of Engagement                               402.0    NaN
# The Ridiculous 6                                11000.0    NaN
# Sex and the City                                  479.0    NaN
# Anger Management                                  676.0    NaN
# Unforgotten                                       132.0    NaN
# A Touch of Frost                                    5.0    NaN
# Twisted                                           398.0    NaN
# Defiance                                          600.0    NaN
# Outlander                                         184.0    NaN
# The Returned                                      114.0    NaN
# McHale's Navy                                     253.0    NaN
# Animal Kingdom: Let's go Ape                        6.0    NaN
# ...                                                 ...    ...
# Home Movies                                         6.0    NaN
# Revolution                                        576.0    NaN
# The Big Swap                                        2.0    NaN
# Midnight Cabaret                                   87.0    NaN
# Happy Valley                                      250.0    NaN
# On the Outs                                        41.0    NaN
# Exam                                              289.0    NaN
# Sunday School Musical                              73.0    NaN
# Ink                                                76.0    NaN
# Jesus People                                      152.0    NaN
# Butterfly                                         180.0    NaN
# Solitude                                           15.0    NaN
# Ordet                                               0.0    NaN
# H.                                                 75.0    NaN
# When the Lights Went Out                          115.0    NaN
# Heroes of Dirt                                     21.0    NaN
# Open Secret                                        75.0    NaN
# The Night Visitor                                  13.0    NaN
# Supporting Characters                             272.0    NaN
# The Dirties                                         8.0    NaN
# Gabriela                                            3.0    NaN
# The Naked Ape                                      15.0    NaN
# Mutual Appreciation                                 3.0    NaN
# Funny Ha Ha                                         3.0    NaN
# Rampage                                           492.0    NaN
# Exeter                                            265.0    NaN
# On the Downlow                                     12.0    NaN
# Bang                                              152.0    NaN
# Signed Sealed Delivered                           318.0    NaN
# The Following                                     319.0    NaN
#
#                                                                                      genres  \
# title
# Star Wars: Episode VII - The Force Awakens                                      Documentary
# The Lovers                                                  Action|Adventure|Romance|Sci-Fi
# Godzilla Resurgence                                    Action|Adventure|Drama|Horror|Sci-Fi
# Harry Potter and the Deathly Hallows: Part II                                Action|Fantasy
# Harry Potter and the Deathly Hallows: Part I                                        Fantasy
# The A-Team                                                           Action|Adventure|Crime
# 10,000 B.C.                                                                          Comedy
# Ben-Hur                                                             Adventure|Drama|History
# Hannibal                                                Crime|Drama|Horror|Mystery|Thriller
# All That Jazz                                                    Comedy|Drama|Music|Musical
# Daredevil                                      Action|Adventure|Crime|Drama|Sci-Fi|Thriller
# Bewitched                                                             Comedy|Family|Fantasy
# Evolution                                                       Drama|Horror|Mystery|Sci-Fi
# Constantine                                                   Drama|Fantasy|Horror|Thriller
# Life                                                                    Crime|Drama|Mystery
# Sleepy Hollow                                      Adventure|Drama|Fantasy|Mystery|Thriller
# Last Man Standing                                                                    Comedy
# The Missing                                                             Crime|Drama|Mystery
# Rules of Engagement                                                          Comedy|Romance
# The Ridiculous 6                                                             Comedy|Western
# Sex and the City                                                             Comedy|Romance
# Anger Management                                                             Comedy|Romance
# Unforgotten                                                                     Crime|Drama
# A Touch of Frost                                                        Crime|Drama|Mystery
# Twisted                                                              Drama|Mystery|Thriller
# Defiance                                                                Action|Drama|Sci-Fi
# Outlander                                                              Drama|Romance|Sci-Fi
# The Returned                                                   Drama|Fantasy|Horror|Mystery
# McHale's Navy                                                                    Comedy|War
# Animal Kingdom: Let's go Ape                              Adventure|Animation|Comedy|Family
# ...                                                                                     ...
# Home Movies                                                          Animation|Comedy|Drama
# Revolution                                                    Action|Adventure|Drama|Sci-Fi
# The Big Swap                                                                          Drama
# Midnight Cabaret                                                                     Horror
# Happy Valley                                                                    Crime|Drama
# On the Outs                                                                           Drama
# Exam                                                                       Mystery|Thriller
# Sunday School Musical                                                         Drama|Musical
# Ink                                                             Action|Drama|Fantasy|Sci-Fi
# Jesus People                                                                   Comedy|Short
# Butterfly                                                                       Crime|Drama
# Solitude                                                     Comedy|Horror|Mystery|Thriller
# Ordet                                                                         Drama|Fantasy
# H.                                                                    Drama|Sci-Fi|Thriller
# When the Lights Went Out                                                             Horror
# Heroes of Dirt                                                           Action|Drama|Sport
# Open Secret                                                                     Crime|Drama
# The Night Visitor                                                     Crime|Horror|Thriller
# Supporting Characters                                                                Comedy
# The Dirties                                                            Crime|Drama|Thriller
# Gabriela                                                               Comedy|Drama|Romance
# The Naked Ape                                                                  Comedy|Drama
# Mutual Appreciation                                                                  Comedy
# Funny Ha Ha                                                                    Comedy|Drama
# Rampage                                                               Action|Crime|Thriller
# Exeter                                                              Horror|Mystery|Thriller
# On the Downlow                                                                        Drama
# Bang                                                                            Crime|Drama
# Signed Sealed Delivered                                                        Comedy|Drama
# The Following                                                  Crime|Drama|Mystery|Thriller
#
#                                               num_reviews  num_voted_users  \
# title
# Star Wars: Episode VII - The Force Awakens            NaN                8
# The Lovers                                           10.0             2138
# Godzilla Resurgence                                   1.0              374
# Harry Potter and the Deathly Hallows: Part II         1.0              381
# Harry Potter and the Deathly Hallows: Part I          4.0              252
# The A-Team                                           29.0            25402
# 10,000 B.C.                                           NaN                6
# Ben-Hur                                               1.0               57
# Hannibal                                            103.0           159910
# All That Jazz                                        84.0            19228
# Daredevil                                            95.0           213483
# Bewitched                                            31.0            11427
# Evolution                                            63.0              979
# Constantine                                          12.0            36919
# Life                                                 12.0            29450
# Sleepy Hollow                                        39.0            49049
# Last Man Standing                                     4.0            15114
# The Missing                                          14.0             8739
# Rules of Engagement                                   8.0            26404
# The Ridiculous 6                                     53.0            27019
# Sex and the City                                     46.0            80025
# Anger Management                                     26.0            26992
# Unforgotten                                           2.0             1824
# A Touch of Frost                                     14.0             4438
# Twisted                                               4.0             7945
# Defiance                                             28.0            33535
# Outlander                                            30.0            50391
# The Returned                                         23.0            15762
# McHale's Navy                                         4.0             1558
# Animal Kingdom: Let's go Ape                          9.0              590
# ...                                                   ...              ...
# Home Movies                                          11.0             7458
# Revolution                                           23.0            72017
# The Big Swap                                          4.0              270
# Midnight Cabaret                                      1.0               47
# Happy Valley                                         11.0            12848
# On the Outs                                          26.0              603
# Exam                                                 77.0            70076
# Sunday School Musical                                 5.0              602
# Ink                                                  66.0            18486
# Jesus People                                          NaN               31
# Butterfly                                            15.0              870
# Solitude                                              1.0               78
# Ordet                                                54.0             9903
# H.                                                   18.0              191
# When the Lights Went Out                             44.0             3813
# Heroes of Dirt                                        2.0               53
# Open Secret                                           1.0               67
# The Night Visitor                                    14.0              544
# Supporting Characters                                15.0              760
# The Dirties                                          73.0             3885
# Gabriela                                              1.0              712
# The Naked Ape                                         NaN              128
# Mutual Appreciation                                  52.0             1578
# Funny Ha Ha                                          43.0             1894
# Rampage                                              58.0            15091
# Exeter                                               43.0             3836
# On the Downlow                                        NaN              156
# Bang                                                 10.0              438
# Signed Sealed Delivered                               1.0              629
# The Following                                        43.0            73839
#
#                                                                                    plot_keywords  \
# title
# Star Wars: Episode VII - The Force Awakens                                                   NaN
# The Lovers                                     1770s|british india|great barrier reef|india|ring
# Godzilla Resurgence                                                blood|godzilla|monster|sequel
# Harry Potter and the Deathly Hallows: Part II                                                NaN
# Harry Potter and the Deathly Hallows: Part I                                                 NaN
# The A-Team                                     1980s|cult tv|famous opening theme|good versus...
# 10,000 B.C.                                                                                  NaN
# Ben-Hur                                                                                      NaN
# Hannibal                                         blood|cannibalism|fbi|manipulation|psychiatrist
# All That Jazz                                  dancer|editing|stand up comedian|surgery|vomiting
# Daredevil                                      corruption|lawyer|partnership|superhero|vigilante
# Bewitched                                            connecticut|magic|marriage|witch|witchcraft
# Evolution                                             boy|giving birth|nurse|sea|ultrasonography
# Constantine                                    based on comic|based on comic book|dc arrowver...
# Life                                                   cop|murder|partner|police|protective male
# Sleepy Hollow                                  apocalypse|death|husband wife relationship|mot...
# Last Man Standing                              family relationships|husband wife relationship...
# The Missing                                     france|journalist|limp|police detective|reporter
# Rules of Engagement                             fiance|fiancee|magazine editor|naivety|womanizer
# The Ridiculous 6                               apache|bank robbery|baseball|half brothers|whi...
# Sex and the City                               casual sex|friendship|friendship between women...
# Anger Management                               anger management|argument|irony|sarcasm|therapist
# Unforgotten                                                                                  NaN
# A Touch of Frost                               cult tv|death|detective inspector|four word ti...
# Twisted                                                                                      NaN
# Defiance                                       alien|alien invasion|planet invasion|post apoc...
# Outlander                                      based on novel|clan|scotland|scottish highland...
# The Returned                                   france|living dead|serial killer|small town|su...
# McHale's Navy                                  american soldier|naval uniform|navy|patrol boa...
# Animal Kingdom: Let's go Ape                   ape|computer animation|evolution|first person ...
# ...                                                                                          ...
# Home Movies                                                 coach|friend|school|series|tv series
# Revolution                                     2020s|near future|one word series title|post a...
# The Big Swap                                   breasts|female frontal nudity|jealousy|male fu...
# Midnight Cabaret                               cigarette smoking|death|devil|nightmare|satani...
# Happy Valley                                   caravan|police|police sergeant|tied to a chair...
# On the Outs                                    dominican|drug dealer|prison|single mother|tee...
# Exam                                           band aid|hairpin|one day|single set production...
# Sunday School Musical                           church|competition|high school|new school|pastor
# Ink                                            dream|self destructiveness|storyteller|time pa...
# Jesus People                                            mockumentary|single camera|subtle comedy
# Butterfly                                      breasts|female frontal nudity|female rear nudi...
# Solitude                                                                                     NaN
# Ordet                                                       august|doctor|faith|patriarch|prayer
# H.                                                                                           NaN
# When the Lights Went Out                       father daughter relationship|poltergeist|spiri...
# Heroes of Dirt                                                bike|bmx|drugs|troubled teen|youth
# Open Secret                                                               anti semitism|gangster
# The Night Visitor                              escape|independent film|mental illness|prison|...
# Supporting Characters                          film editor|kiss|marriage proposal|movie scree...
# The Dirties                                              best friend|bully|friend|revenge|school
# Gabriela                                       based on novel|brazil|female underarm hair|sex...
# The Naked Ape                                  coming of age|male nudity|road trip|skinny dip...
# Mutual Appreciation                            friendship|guitarist|mumblecore|musician|new york
# Funny Ha Ha                                                                           mumblecore
# Rampage                                           death|first part|killing spree|massacre|murder
# Exeter                                                        asylum|demon|party|secret|teenager
# On the Downlow                                 gang initiation|gunplay|hazing|latino|shakespe...
# Bang                                           corruption|homeless|homeless man|motorcycle|ur...
# Signed Sealed Delivered                                   fraud|postal worker|prison|theft|trial
# The Following                                       cult|fbi|hideout|prison escape|serial killer
#
#                                                  language  country budget  \
# title
# Star Wars: Episode VII - The Force Awakens            NaN      NaN    NaN
# The Lovers                                        English  Belgium    NaN
# Godzilla Resurgence                              Japanese    Japan    NaN
# Harry Potter and the Deathly Hallows: Part II     English       UK    NaN
# Harry Potter and the Deathly Hallows: Part I      English       UK    NaN
# The A-Team                                        English      USA    NaN
# 10,000 B.C.                                           NaN      NaN    NaN
# Ben-Hur                                           English      USA    NaN
# Hannibal                                          English      USA    NaN
# All That Jazz                                     English      USA    NaN
# Daredevil                                         English      USA    NaN
# Bewitched                                         English      USA    NaN
# Evolution                                          French   France    NaN
# Constantine                                       English      USA    NaN
# Life                                              English      USA    NaN
# Sleepy Hollow                                     English      USA    NaN
# Last Man Standing                                 English      USA    NaN
# The Missing                                       English       UK    NaN
# Rules of Engagement                               English      USA    NaN
# The Ridiculous 6                                  English      USA    NaN
# Sex and the City                                  English      USA    NaN
# Anger Management                                  English      USA    NaN
# Unforgotten                                       English       UK    NaN
# A Touch of Frost                                  English       UK    NaN
# Twisted                                           English      USA    NaN
# Defiance                                          English      USA    NaN
# Outlander                                         English      USA    NaN
# The Returned                                       French   France    NaN
# McHale's Navy                                     English      USA    NaN
# Animal Kingdom: Let's go Ape                       French   France    NaN
# ...                                                   ...      ...    ...
# Home Movies                                       English      USA    NaN
# Revolution                                        English      USA    NaN
# The Big Swap                                      English       UK    NaN
# Midnight Cabaret                                  English      USA    NaN
# Happy Valley                                      English       UK    NaN
# On the Outs                                       English      USA    NaN
# Exam                                              English       UK    NaN
# Sunday School Musical                             English      USA    NaN
# Ink                                               English      USA    NaN
# Jesus People                                      English      USA    NaN
# Butterfly                                         English      USA    NaN
# Solitude                                          English      USA    NaN
# Ordet                                              Danish  Denmark    NaN
# H.                                                English      USA    NaN
# When the Lights Went Out                          English       UK    NaN
# Heroes of Dirt                                    English      USA    NaN
# Open Secret                                       English      USA    NaN
# The Night Visitor                                 English      USA    NaN
# Supporting Characters                             English      USA    NaN
# The Dirties                                       English   Canada    NaN
# Gabriela                                       Portuguese   Brazil    NaN
# The Naked Ape                                     English      USA    NaN
# Mutual Appreciation                               English      USA    NaN
# Funny Ha Ha                                       English      USA    NaN
# Rampage                                           English   Canada    NaN
# Exeter                                            English      USA    NaN
# On the Downlow                                    English      USA    NaN
# Bang                                              English      USA    NaN
# Signed Sealed Delivered                           English   Canada    NaN
# The Following                                     English      USA    NaN
#
#                                                imdb_score
# title
# Star Wars: Episode VII - The Force Awakens            7.1
# The Lovers                                            4.5
# Godzilla Resurgence                                   8.2
# Harry Potter and the Deathly Hallows: Part II         7.5
# Harry Potter and the Deathly Hallows: Part I          6.4
# The A-Team                                            7.6
# 10,000 B.C.                                           7.2
# Ben-Hur                                               6.1
# Hannibal                                              8.6
# All That Jazz                                         7.8
# Daredevil                                             8.8
# Bewitched                                             7.6
# Evolution                                             6.4
# Constantine                                           7.5
# Life                                                  8.3
# Sleepy Hollow                                         7.5
# Last Man Standing                                     7.4
# The Missing                                           8.1
# Rules of Engagement                                   7.3
# The Ridiculous 6                                      4.9
# Sex and the City                                      7.0
# Anger Management                                      6.7
# Unforgotten                                           7.9
# A Touch of Frost                                      7.8
# Twisted                                               7.5
# Defiance                                              7.0
# Outlander                                             8.5
# The Returned                                          8.3
# McHale's Navy                                         7.5
# Animal Kingdom: Let's go Ape                          4.9
# ...                                                   ...
# Home Movies                                           8.2
# Revolution                                            6.7
# The Big Swap                                          5.6
# Midnight Cabaret                                      4.5
# Happy Valley                                          8.5
# On the Outs                                           6.9
# Exam                                                  6.9
# Sunday School Musical                                 2.5
# Ink                                                   7.0
# Jesus People                                          6.9
# Butterfly                                             4.5
# Solitude                                              6.8
# Ordet                                                 8.1
# H.                                                    6.3
# When the Lights Went Out                              5.4
# Heroes of Dirt                                        7.1
# Open Secret                                           7.1
# The Night Visitor                                     6.8
# Supporting Characters                                 6.3
# The Dirties                                           6.7
# Gabriela                                              6.4
# The Naked Ape                                         4.7
# Mutual Appreciation                                   6.9
# Funny Ha Ha                                           6.4
# Rampage                                               6.3
# Exeter                                                4.6
# On the Downlow                                        6.1
# Bang                                                  6.4
# Signed Sealed Delivered                               7.7
# The Following                                         7.5
#
# [219 rows x 21 columns]

# %% [markdown]
# ### Problem 8
# <span  style="color:green; font-size:16px">Write a function `find_missing` that has three parameters, `df`, `col1` and `col2` where `df` is a DataFrame and `col1` and `col2` are column names. This function should return all the rows of the DataFrame where `col1` and `col2` are missing. Only return the two columns as well. Answer problem 7 with this function.</span>

# %%
# your code here
def find_missing(df, col1, col2):
    filt1 = df[col1].isna()
    filt2 = df[col2].isna()
    filt = filt1 & filt2
    cols = [col1, col2]
    return df.loc[filt, cols]

# %%
find_missing(movies, 'gross', 'budget')
# Out:
#                                                gross  budget
# title
# Star Wars: Episode VII - The Force Awakens       NaN     NaN
# The Lovers                                       NaN     NaN
# Godzilla Resurgence                              NaN     NaN
# Harry Potter and the Deathly Hallows: Part II    NaN     NaN
# Harry Potter and the Deathly Hallows: Part I     NaN     NaN
# The A-Team                                       NaN     NaN
# 10,000 B.C.                                      NaN     NaN
# Ben-Hur                                          NaN     NaN
# Hannibal                                         NaN     NaN
# All That Jazz                                    NaN     NaN
# Daredevil                                        NaN     NaN
# Bewitched                                        NaN     NaN
# Evolution                                        NaN     NaN
# Constantine                                      NaN     NaN
# Life                                             NaN     NaN
# Sleepy Hollow                                    NaN     NaN
# Last Man Standing                                NaN     NaN
# The Missing                                      NaN     NaN
# Rules of Engagement                              NaN     NaN
# The Ridiculous 6                                 NaN     NaN
# Sex and the City                                 NaN     NaN
# Anger Management                                 NaN     NaN
# Unforgotten                                      NaN     NaN
# A Touch of Frost                                 NaN     NaN
# Twisted                                          NaN     NaN
# Defiance                                         NaN     NaN
# Outlander                                        NaN     NaN
# The Returned                                     NaN     NaN
# McHale's Navy                                    NaN     NaN
# Animal Kingdom: Let's go Ape                     NaN     NaN
# ...                                              ...     ...
# Home Movies                                      NaN     NaN
# Revolution                                       NaN     NaN
# The Big Swap                                     NaN     NaN
# Midnight Cabaret                                 NaN     NaN
# Happy Valley                                     NaN     NaN
# On the Outs                                      NaN     NaN
# Exam                                             NaN     NaN
# Sunday School Musical                            NaN     NaN
# Ink                                              NaN     NaN
# Jesus People                                     NaN     NaN
# Butterfly                                        NaN     NaN
# Solitude                                         NaN     NaN
# Ordet                                            NaN     NaN
# H.                                               NaN     NaN
# When the Lights Went Out                         NaN     NaN
# Heroes of Dirt                                   NaN     NaN
# Open Secret                                      NaN     NaN
# The Night Visitor                                NaN     NaN
# Supporting Characters                            NaN     NaN
# The Dirties                                      NaN     NaN
# Gabriela                                         NaN     NaN
# The Naked Ape                                    NaN     NaN
# Mutual Appreciation                              NaN     NaN
# Funny Ha Ha                                      NaN     NaN
# Rampage                                          NaN     NaN
# Exeter                                           NaN     NaN
# On the Downlow                                   NaN     NaN
# Bang                                             NaN     NaN
# Signed Sealed Delivered                          NaN     NaN
# The Following                                    NaN     NaN
#
# [219 rows x 2 columns]
